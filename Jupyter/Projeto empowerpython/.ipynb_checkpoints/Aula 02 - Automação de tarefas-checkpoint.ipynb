# %% [markdown]
# # Cenário: Trabalha em uma empresa de investimentos.
#
# ### Objetivo: Enviar um e-mail todos os dias com análise das cotações de algumas ações.
#
# ### Passo a passo do problema
#
# - Passo 1: Buscar dados das ações automaticamente.
# - Passo 2: Realizar as análises solicitadas pelo meu gestor.
# - Passo 3: Enviar automaticamente o email com o resultado da análise.

# %% [markdown]
# # Passo 1
#
# Instalar as bibliotecas para serem consumidas no projeot.

# %%
# !pip install yfinance

# %%
import yfinance as yf


dados = yf.Ticker("PETR4.SA").history("6mo")
fechamento = dados.Close
fechamento
# Out:
# Date
# 2022-12-12 00:00:00-03:00    21.280365
# 2022-12-13 00:00:00-03:00    20.755253
# 2022-12-14 00:00:00-03:00    19.108717
# 2022-12-15 00:00:00-03:00    19.616028
# 2022-12-16 00:00:00-03:00    19.624928
#                                ...
# 2023-06-05 00:00:00-03:00    27.469999
# 2023-06-06 00:00:00-03:00    28.049999
# 2023-06-07 00:00:00-03:00    28.870001
# 2023-06-09 00:00:00-03:00    30.280001
# 2023-06-12 00:00:00-03:00    30.809999
# Name: Close, Length: 124, dtype: float64

# %%
ticker = input("Digite o código da ação: ")
dados = yf.Ticker(ticker).history("6mo")
fechamento = dados.Close
fechamento
# Out:
# Digite o código da ação: BBAS3.SA
# Date
# 2022-12-12 00:00:00-03:00    32.009880
# 2022-12-13 00:00:00-03:00    30.493372
# 2022-12-14 00:00:00-03:00    29.737257
# 2022-12-15 00:00:00-03:00    30.579510
# 2022-12-16 00:00:00-03:00    31.201628
#                                ...
# 2023-06-05 00:00:00-03:00    45.020000
# 2023-06-06 00:00:00-03:00    45.540001
# 2023-06-07 00:00:00-03:00    45.520000
# 2023-06-09 00:00:00-03:00    47.740002
# 2023-06-12 00:00:00-03:00    49.470001
# Name: Close, Length: 124, dtype: float64

# %%
fechamento.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Passo 2
# - Cotação máxima
# - Cotação mínima
# - Cotação atual

# %%
fechamento
# Out:
# Date
# 2022-12-12 00:00:00-03:00    21.280365
# 2022-12-13 00:00:00-03:00    20.755253
# 2022-12-14 00:00:00-03:00    19.108717
# 2022-12-15 00:00:00-03:00    19.616028
# 2022-12-16 00:00:00-03:00    19.624928
#                                ...
# 2023-06-05 00:00:00-03:00    27.469999
# 2023-06-06 00:00:00-03:00    28.049999
# 2023-06-07 00:00:00-03:00    28.870001
# 2023-06-09 00:00:00-03:00    30.280001
# 2023-06-12 00:00:00-03:00    30.629999
# Name: Close, Length: 124, dtype: float64

# %%
maxima = round(fechamento.max(),2)
minima = round(fechamento.min(),2)
atual = round(fechamento[-1],2)

print(maxima)
print(minima)
print(atual)
# Out:
# 49.47
# 29.74
# 49.47

# %% [markdown]
# # Passo 3:
# - Enviar automaticamente o email com o resultado da análise.
# - Automação:
# - Abrir uma nova aba (CTRL + TAB);
# - Digitar www.gmail.com na barra de endereço e acionar o (ENTER);
# - Clicar no botão escrever;
# - Digitar o destinatário (TAB);
# - Digitar o assunto (TAB);
# - Digitar o corpo do e-mail (TAB);
# - Clicar no botão enviar.

# %%
# !pip install pyautogui

# %%
# !pip install pyperclip

# %%
import pyautogui
import pyperclip

# %%
# pausar 2 segundos entre as etapas.
pyautogui.PAUSE = 2

# Abrir uma nova aba (CTRL + TAB);
pyautogui.hotkey("ctrl","t")

# Digitar www.gmail.com na barra de endereço e acionar o (ENTER);
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("enter")

# Clicar no botão escrever;
pyautogui.click(x=85, y=198)

# Digitar o destinatário (TAB);
pyperclip.copy("suporte2@planosmetropax.com.br")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")

# Digitar o assunto (TAB);
pyperclip.copy("Teste de Automação Python")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")

# Digitar o corpo do e-mail (TAB);
mensagem = f"""
Prezado Gestor, 

Seguem, conforme solicitado, as análises dos últimos seis meses da ação {ticker}:

Cotação máxima: R$ {maxima}
Cotação mínima: R$ {minima}
Cotação atual:  R$ {atual}

Qualquer dúvida, fico à disposição!


Atenciosamente.

"""

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl","v")


# Clicar no botão enviar.
pyautogui.click(x=896, y=695)

# %%
# Para identificar a posição dos botões de comando, exemplo: Escrever.
# Posicionar no respectivo botão para retornar as coordenadas.

import time
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=896, y=695)
